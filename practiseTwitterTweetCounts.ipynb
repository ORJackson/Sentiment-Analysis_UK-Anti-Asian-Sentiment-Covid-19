# %%
from pandas import json_normalize
import pip._vendor.requests 
import os
import json
from dotenv import load_dotenv
import csv
import pandas as pd

load_dotenv()

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
bearer_token = os.environ.get("BEARER-TOKEN")

search_url = "https://api.twitter.com/2/tweets/counts/all"

# Optional params: start_time,end_time,since_id,until_id,next_token,granularity
# query_params = {'query': 'china lang:en -is:retweet OR covid lang:en -is:retweet','granularity': 'day', 'start_time': '2021-01-01T00:00:00Z', 'end_time': '2021-03-01T00:00:00Z', 'next_token': {}}
def query_params(next_token):
    return {'query': 'china lang:en -is:retweet OR covid lang:en -is:retweet','granularity': 'day', 'start_time': '2021-01-01T00:00:00Z', 'end_time': '2021-03-01T00:00:00Z', 'next_token': next_token}


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FullArchiveTweetCountsPython"
    return r


def connect_to_endpoint(url, params):
    response = pip._vendor.requests.request("GET", search_url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()





def main():
    next_token = {}
    finished = False
    while finished == False:
        json_response = connect_to_endpoint(search_url, query_params(next_token))
        print(json.dumps(json_response, indent=4, sort_keys=True))
        if 'next_token' in json_response['meta']:
            # Save the token to use for next call
            next_token = json_response['meta']['next_token']
        else:
            finished = True


# def main():

#     csvFile = open("tweetCounts.csv", "a", newline = "", encoding = "utf-8")
#     csvWriter = csv.writer(csvFile)

#     #creating headers
#     csvWriter.writerow(['start', 'end', 'tweet count'])
    


#     next_token = {}
#     finished = False
#     while finished == False:
#         json_response = connect_to_endpoint(search_url, query_params(next_token))
#         # print(json.dumps(json_response, indent=4, sort_keys=True))
#         for data in json_response:
#             # for countData in data['data']:
#                 # start = countData['start']
#                 # end = countData['end']
#                 # count = countData['tweet_count']
#             for countData in data[0]:
#                 start = countData[0]
#                 end = countData[1]
#                 count = countData[2]

#                 result = [start, end, count]
#                 csvWriter.writeRow(result)
        
#         if 'next_token' in json_response['meta']:
#             # Save the token to use for next call
#             next_token = json_response['meta']['next_token']
#         else:
#             finished = True
    


#     csvFile.close()


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "end": "2021-02-13T00:00:00.000Z",
#             "start": "2021-02-12T00:00:00.000Z",
#             "tweet_count": 425655
#         },
#         {
#             "end": "2021-02-14T00:00:00.000Z",
#             "start": "2021-02-13T00:00:00.000Z",
#             "tweet_count": 275121
#         },
#         {
#             "end": "2021-02-15T00:00:00.000Z",
#             "start": "2021-02-14T00:00:00.000Z",
#             "tweet_count": 238364
#         },
#         {
#             "end": "2021-02-16T00:00:00.000Z",
#             "start": "2021-02-15T00:00:00.000Z",
#             "tweet_count": 301957
#         },
#         {
#             "end": "2021-02-17T00:00:00.000Z",
#             "start": "2021-02-16T00:00:00.000Z",
#             "tweet_count": 325415
#         },
#         {
#             "end": "2021-02-18T00:00:00.000Z",
#             "start": "2021-02-17T00:00:00.000Z",
#             "tweet_count": 336549
#         },
#         {
#             "end": "2021-02-19T00:00:00.000Z",
#             "start": "2021-02-18T00:00:00.000Z",
#             "tweet_count": 317762
#         },
#         {
#             "end": "2021-02-20T00:00:00.000Z",
#             "start": "2021-02-19T00:00:00.000Z",
#             "tweet_count": 320687
#         },
#         {
#             "end": "2021-02-21T00:00:00.000Z",
#             "start": "2021-02-20T00:00:00.000Z",
#             "tweet_count": 247737
#         },
#         {
#             "end": "2021-02-22T00:00:00.000Z",
#             "start": "2021-02-21T00:00:00.000Z",
#             "tweet_count": 246251
#         },
#         {
#             "end": "2021-02-23T00:00:00.000Z",
#             "start": "2021-02-22T00:00:00.000Z",
#             "tweet_count": 329617
#         },
#         {
#             "end": "2021-02-24T00:00:00.000Z",
#             "start": "2021-02-23T00:00:00.000Z",
#             "tweet_count": 338935
#         },
#         {
#             "end": "2021-02-25T00:00:00.000Z",
#             "start": "2021-02-24T00:00:00.000Z",
#             "tweet_count": 336244
#         },
#         {
#             "end": "2021-02-26T00:00:00.000Z",
#             "start": "2021-02-25T00:00:00.000Z",
#             "tweet_count": 325582
#         },
#         {
#             "end": "2021-02-27T00:00:00.000Z",
#             "start": "2021-02-26T00:00:00.000Z",
#             "tweet_count": 318915
#         },
#         {
#             "end": "2021-02-28T00:00:00.000Z",
#             "start": "2021-02-27T00:00:00.000Z",
#             "tweet_count": 271977
#         },
#         {
#             "end": "2021-03-01T00:00:00.000Z",
#             "start": "2021-02-28T00:00:00.000Z",
#             "tweet_count": 253654
#         }
#     ],
#     "meta": {
#         "next_token": "1jzu9lk96azp0b3x7888hrpw8fftmvoa0p34g2s8wd4t",
#         "total_tweet_count": 5210422
#     }
# }
# 200
# {
#     "data": [
#         {
#             "end": "2021-01-27T00:00:00.000Z",
#             "start": "2021-01-26T00:00:00.000Z",
#             "tweet_count": 425666
#         },
#         {
#             "end": "2021-01-28T00:00:00.000Z",
#             "start": "2021-01-27T00:00:00.000Z",
#             "tweet_count": 432620
#         },
#         {
#             "end": "2021-01-29T00:00:00.000Z",
#             "start": "2021-01-28T00:00:00.000Z",
#             "tweet_count": 393600
#         },
#         {
#             "end": "2021-01-30T00:00:00.000Z",
#             "start": "2021-01-29T00:00:00.000Z",
#             "tweet_count": 375362
#         },
#         {
#             "end": "2021-01-31T00:00:00.000Z",
#             "start": "2021-01-30T00:00:00.000Z",
#             "tweet_count": 295187
#         },
#         {
#             "end": "2021-02-01T00:00:00.000Z",
#             "start": "2021-01-31T00:00:00.000Z",
#             "tweet_count": 302631
#         },
#         {
#             "end": "2021-02-02T00:00:00.000Z",
#             "start": "2021-02-01T00:00:00.000Z",
#             "tweet_count": 354646
#         },
#         {
#             "end": "2021-02-03T00:00:00.000Z",
#             "start": "2021-02-02T00:00:00.000Z",
#             "tweet_count": 369968
#         },
#         {
#             "end": "2021-02-04T00:00:00.000Z",
#             "start": "2021-02-03T00:00:00.000Z",
#             "tweet_count": 378371
#         },
#         {
#             "end": "2021-02-05T00:00:00.000Z",
#             "start": "2021-02-04T00:00:00.000Z",
#             "tweet_count": 366755
#         },
#         {
#             "end": "2021-02-06T00:00:00.000Z",
#             "start": "2021-02-05T00:00:00.000Z",
#             "tweet_count": 348013
#         },
#         {
#             "end": "2021-02-07T00:00:00.000Z",
#             "start": "2021-02-06T00:00:00.000Z",
#             "tweet_count": 270176
#         },
#         {
#             "end": "2021-02-08T00:00:00.000Z",
#             "start": "2021-02-07T00:00:00.000Z",
#             "tweet_count": 259608
#         },
#         {
#             "end": "2021-02-09T00:00:00.000Z",
#             "start": "2021-02-08T00:00:00.000Z",
#             "tweet_count": 343644
#         },
#         {
#             "end": "2021-02-10T00:00:00.000Z",
#             "start": "2021-02-09T00:00:00.000Z",
#             "tweet_count": 340762
#         },
#         {
#             "end": "2021-02-11T00:00:00.000Z",
#             "start": "2021-02-10T00:00:00.000Z",
#             "tweet_count": 413411
#         },
#         {
#             "end": "2021-02-12T00:00:00.000Z",
#             "start": "2021-02-11T00:00:00.000Z",
#             "tweet_count": 382172
#         }
#     ],
#     "meta": {
#         "next_token": "1jzu9lk96azp0b3x7888hrpw8ffthflbg04hwq5l0519",
#         "total_tweet_count": 6052592
#     }
# }
# 200
# {
#     "data": [
#         {
#             "end": "2021-01-12T00:00:00.000Z",
#             "start": "2021-01-11T00:00:00.000Z",
#             "tweet_count": 398262
#         },
#         {
#             "end": "2021-01-13T00:00:00.000Z",
#             "start": "2021-01-12T00:00:00.000Z",
#             "tweet_count": 445137
#         },
#         {
#             "end": "2021-01-14T00:00:00.000Z",
#             "start": "2021-01-13T00:00:00.000Z",
#             "tweet_count": 410934
#         },
#         {
#             "end": "2021-01-15T00:00:00.000Z",
#             "start": "2021-01-14T00:00:00.000Z",
#             "tweet_count": 402844
#         },
#         {
#             "end": "2021-01-16T00:00:00.000Z",
#             "start": "2021-01-15T00:00:00.000Z",
#             "tweet_count": 418342
#         },
#         {
#             "end": "2021-01-17T00:00:00.000Z",
#             "start": "2021-01-16T00:00:00.000Z",
#             "tweet_count": 348478
#         },
#         {
#             "end": "2021-01-18T00:00:00.000Z",
#             "start": "2021-01-17T00:00:00.000Z",
#             "tweet_count": 313944
#         },
#         {
#             "end": "2021-01-19T00:00:00.000Z",
#             "start": "2021-01-18T00:00:00.000Z",
#             "tweet_count": 359697
#         },
#         {
#             "end": "2021-01-20T00:00:00.000Z",
#             "start": "2021-01-19T00:00:00.000Z",
#             "tweet_count": 431878
#         },
#         {
#             "end": "2021-01-21T00:00:00.000Z",
#             "start": "2021-01-20T00:00:00.000Z",
#             "tweet_count": 422403
#         },
#         {
#             "end": "2021-01-22T00:00:00.000Z",
#             "start": "2021-01-21T00:00:00.000Z",
#             "tweet_count": 430929
#         },
#         {
#             "end": "2021-01-23T00:00:00.000Z",
#             "start": "2021-01-22T00:00:00.000Z",
#             "tweet_count": 424682
#         },
#         {
#             "end": "2021-01-24T00:00:00.000Z",
#             "start": "2021-01-23T00:00:00.000Z",
#             "tweet_count": 346719
#         },
#         {
#             "end": "2021-01-25T00:00:00.000Z",
#             "start": "2021-01-24T00:00:00.000Z",
#             "tweet_count": 332080
#         },
#         {
#             "end": "2021-01-26T00:00:00.000Z",
#             "start": "2021-01-25T00:00:00.000Z",
#             "tweet_count": 424756
#         }
#     ],
#     "meta": {
#         "next_token": "1jzu9lk96azp0b3x7888hrpw8ffthet3cxf17zoumet9",
#         "total_tweet_count": 5911085
#     }
# }
# 200
# {
#     "data": [
#         {
#             "end": "2021-01-02T00:00:00.000Z",
#             "start": "2021-01-01T00:00:00.000Z",
#             "tweet_count": 377003
#         },
#         {
#             "end": "2021-01-03T00:00:00.000Z",
#             "start": "2021-01-02T00:00:00.000Z",
#             "tweet_count": 374763
#         },
#         {
#             "end": "2021-01-04T00:00:00.000Z",
#             "start": "2021-01-03T00:00:00.000Z",
#             "tweet_count": 395055
#         },
#         {
#             "end": "2021-01-05T00:00:00.000Z",
#             "start": "2021-01-04T00:00:00.000Z",
#             "tweet_count": 446996
#         },
#         {
#             "end": "2021-01-06T00:00:00.000Z",
#             "start": "2021-01-05T00:00:00.000Z",
#             "tweet_count": 476558
#         },
#         {
#             "end": "2021-01-07T00:00:00.000Z",
#             "start": "2021-01-06T00:00:00.000Z",
#             "tweet_count": 477369
#         },
#         {
#             "end": "2021-01-08T00:00:00.000Z",
#             "start": "2021-01-07T00:00:00.000Z",
#             "tweet_count": 388523
#         },
#         {
#             "end": "2021-01-09T00:00:00.000Z",
#             "start": "2021-01-08T00:00:00.000Z",
#             "tweet_count": 413958
#         },
#         {
#             "end": "2021-01-10T00:00:00.000Z",
#             "start": "2021-01-09T00:00:00.000Z",
#             "tweet_count": 352238
#         },
#         {
#             "end": "2021-01-11T00:00:00.000Z",
#             "start": "2021-01-10T00:00:00.000Z",
#             "tweet_count": 316552
#         }
#     ],
#     "meta": {
#         "total_tweet_count": 4019015
#     }
# }
